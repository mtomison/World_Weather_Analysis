# %%
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import json
from config import weather_api_key
import requests
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations:
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180,high=180, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a ist for holding the cities
cities = []
city_data = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to teh cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 724

# %%
cities
# Out:
# ['atuona',
#  'jamestown',
#  'provideniya',
#  'klaksvik',
#  'tsihombe',
#  'hermanus',
#  'kiunga',
#  'santa cruz del norte',
#  'bluff',
#  'punta arenas',
#  'udachnyy',
#  'tuktoyaktuk',
#  'busselton',
#  'el tigre',
#  'puerto ayora',
#  'ostrovnoy',
#  'manggar',
#  'yagodnoye',
#  'bayan',
#  'clyde river',
#  'port alfred',
#  'bargal',
#  'avarua',
#  'aklavik',
#  'chuy',
#  'mankato',
#  'vaini',
#  'ancud',
#  'mussomeli',
#  'qaanaaq',
#  'butaritari',
#  'huaicheng',
#  'rikitea',
#  'zhangye',
#  'barrow',
#  'balykshi',
#  'los llanos de aridane',
#  'cherskiy',
#  'kichera',
#  'albany',
#  'severo-kurilsk',
#  'bengkulu',
#  'taolanaro',
#  'englehart',
#  'vila',
#  'paamiut',
#  'poum',
#  'sinnamary',
#  'resistencia',
#  'ballina',
#  'new norfolk',
#  'ushuaia',
#  'swellendam',
#  'khatanga',
#  'tanete',
#  'chokwe',
#  'mahebourg',
#  'port blair',
#  'mildura',
#  'fortuna',
#  'mehamn',
#  'cape town',
#  'vila velha',
#  'illoqqortoormiut',
#  'tasiilaq',
#  'hilo',
#  'ngukurr',
#  'saint anthony',
#  'paita',
#  'bosaso',
#  'fuerte olimpo',
#  'norman wells',
#  'arraial do cabo',
#  'chicama',
#  'luderitz',
#  'saint-philippe',
#  'mongo',
#  'port keats',
#  'cazaje',
#  'huicheng',
#  'tungor',
#  'pangkalanbuun',
#  'hami',
#  'fort nelson',
#  'hobart',
#  'saint-joseph',
#  'huaihua',
#  'sentyabrskiy',
#  'arman',
#  'attawapiskat',
#  'kapaa',
#  'nizhneyansk',
#  'buta',
#  'sabang',
#  'noyabrsk',
#  'sao filipe',
#  'porto de moz',
#  'port elizabeth',
#  'olafsvik',
#  'hamza',
#  'portland',
#  'yellowknife',
#  'east london',
#  'gravdal',
#  'kununurra',
#  'cabinda',
#  'lerwick',
#  'port-gentil',
#  'katobu',
#  'morbegno',
#  'mataura',
#  'upernavik',
#  'zatyshshya',
#  'lexington',
#  'lata',
#  'kapit',
#  'ribeira grande',
#  'victoria',
#  'garissa',
#  'bati',
#  'ariogala',
#  'guisijan',
#  'grindavik',
#  'lolua',
#  'port augusta',
#  'kruisfontein',
#  'hirara',
#  'kasama',
#  'qujing',
#  'hithadhoo',
#  'chokurdakh',
#  'saint-pierre',
#  'thompson',
#  'mgandu',
#  'haines junction',
#  'beringovskiy',
#  'tabialan',
#  'coahuayana',
#  'tiksi',
#  'palabuhanratu',
#  'nenjiang',
#  'caohe',
#  'san pedro',
#  'kutum',
#  'andenes',
#  'rio cuarto',
#  'pevek',
#  'san',
#  'mar del plata',
#  'cabo san lucas',
#  'kavieng',
#  'shellbrook',
#  'yumen',
#  'damaturu',
#  'okha',
#  'nyurba',
#  'vysokogornyy',
#  'oudtshoorn',
#  'inuvik',
#  'hofn',
#  'dikson',
#  'padang',
#  'tura',
#  'chapais',
#  'lebu',
#  'lompoc',
#  'bredasdorp',
#  'kensington',
#  'buala',
#  'saskylakh',
#  'carnarvon',
#  'black river',
#  'belushya guba',
#  'rungata',
#  'harper',
#  'geraldton',
#  'xadani',
#  'sitka',
#  'andrews',
#  'tucurui',
#  'karauzyak',
#  'airai',
#  'filadelfia',
#  'faya',
#  'grand gaube',
#  'charters towers',
#  'tilzapotla',
#  'ormara',
#  'kloulklubed',
#  'flinders',
#  'carballo',
#  'jiayuguan',
#  'ponta do sol',
#  'murgasi',
#  'tommot',
#  'qaqortoq',
#  'tres arroyos',
#  'bathsheba',
#  'leningradskiy',
#  'manjacaze',
#  'port hardy',
#  'louisbourg',
#  'tuatapere',
#  'constitucion',
#  'kieta',
#  'yar-sale',
#  'savalou',
#  'rodrigues alves',
#  'kargil',
#  'balakhta',
#  'lasa',
#  'acari',
#  'torbay',
#  'mount isa',
#  'warqla',
#  'moindou',
#  'olinda',
#  'labrea',
#  'gangotri',
#  'bambous virieux',
#  'nizhniy odes',
#  'yeppoon',
#  'avera',
#  'salalah',
#  'redmond',
#  'umzimvubu',
#  'tabiauea',
#  'peruibe',
#  'yuncheng',
#  'cuamba',
#  'port hedland',
#  'castro',
#  'mogadishu',
#  'eyl',
#  'wladyslawowo',
#  'lebork',
#  'luena',
#  'qom',
#  'nikolskoye',
#  'san patricio',
#  'esperance',
#  'ushibuka',
#  'pakxan',
#  'abeche',
#  'zavetnoye',
#  'kushiro',
#  'coihaique',
#  'pangnirtung',
#  'srednekolymsk',
#  'kinablangan',
#  'yalchiki',
#  'pavlovsk',
#  'barawe',
#  'kodiak',
#  'gusau',
#  'igarka',
#  'minab',
#  'pisco',
#  'salinopolis',
#  'perth',
#  'fairbanks',
#  'mangaratiba',
#  'dingle',
#  'bambanglipuro',
#  'korla',
#  'tigil',
#  'narsaq',
#  'hendek',
#  'adrar',
#  'aswan',
#  'hovd',
#  'lander',
#  'whitehorse',
#  'umm lajj',
#  'port lincoln',
#  'nalut',
#  'neiafu',
#  'grand river south east',
#  'mitsamiouli',
#  'amderma',
#  'great bend',
#  'ilulissat',
#  'mys shmidta',
#  'inirida',
#  'georgetown',
#  'kitob',
#  'cidreira',
#  'hobyo',
#  'saldanha',
#  'meulaboh',
#  'pedasi',
#  'xai-xai',
#  'taltal',
#  'gboko',
#  'sobradinho',
#  'santa isabel do rio negro',
#  'tezu',
#  'tambura',
#  'morgan city',
#  'kyzyl-suu',
#  'jalu',
#  'utiroa',
#  'chernigovka',
#  'miri',
#  'las cruces',
#  'slonim',
#  'juneau',
#  'mandalgovi',
#  'gorontalo',
#  'vanimo',
#  'ashland',
#  'ryotsu',
#  'makurdi',
#  'sibiti',
#  'san borja',
#  'banda aceh',
#  'hasaki',
#  'bonavista',
#  'barentsburg',
#  'killybegs',
#  'jipijapa',
#  'gigmoto',
#  'kemijarvi',
#  'muros',
#  'kaitangata',
#  'iskateley',
#  'san cristobal',
#  'saleaula',
#  'vaitupu',
#  'iberia',
#  'petatlan',
#  'general pico',
#  'huinan',
#  'lundazi',
#  'kahului',
#  'katsuura',
#  'tocopilla',
#  'matamoros',
#  'hamilton',
#  'ahipara',
#  'naze',
#  'manacapuru',
#  'solsvik',
#  'bethel',
#  'aksarka',
#  'siderno',
#  'ensenada',
#  'nome',
#  'saint george',
#  'kimbe',
#  'broome',
#  'dunedin',
#  'jackson',
#  'vardo',
#  'mangrol',
#  'armacao dos buzios',
#  'bloemhof',
#  'madang',
#  'urumqi',
#  'huarmey',
#  'chute-aux-outardes',
#  'ust-kamchatsk',
#  'codrington',
#  'orange cove',
#  'shostka',
#  'la spezia',
#  'san quintin',
#  'aflu',
#  'pauini',
#  'souillac',
#  'tomatlan',
#  'bilma',
#  'bursol',
#  'xiongzhou',
#  'ashqelon',
#  'qena',
#  'alice springs',
#  'vanavara',
#  'aitape',
#  'pasighat',
#  'bull savanna',
#  'fairhope',
#  'fare',
#  'matara',
#  'belmonte',
#  'merauke',
#  'guerrero negro',
#  'college',
#  'cumberland',
#  'loa janan',
#  'vestmannaeyjar',
#  'viedma',
#  'novaya ladoga',
#  'nemuro',
#  'bababe',
#  'kralendijk',
#  'khani',
#  'touros',
#  'mandurah',
#  'aberdeen',
#  'faanui',
#  'champerico',
#  'nahavand',
#  'bulancak',
#  'mizan teferi',
#  'grand centre',
#  'tralee',
#  'gerede',
#  'zyryanka',
#  'maniitsoq',
#  'arica',
#  'laguna',
#  'akonolinga',
#  'verkhnevilyuysk',
#  'iqaluit',
#  'oschatz',
#  'la ronge',
#  'saint-leu',
#  'dosso',
#  'forrest city',
#  'pemberton',
#  'huanuco',
#  'vila franca do campo',
#  'assai',
#  'kurilsk',
#  'lugo',
#  'ixtapa',
#  'alappuzha',
#  'hit',
#  'cap malheureux',
#  'sibu',
#  'husavik',
#  'mirpur sakro',
#  'viligili',
#  'westport',
#  'yulara',
#  'carmen',
#  'aken',
#  'quatre cocos',
#  'camacha',
#  'tual',
#  'kuche',
#  'conceicao do araguaia',
#  'kaeo',
#  'lephepe',
#  'soroti',
#  'omsukchan',
#  'alofi',
#  'formoso do araguaia',
#  'salcininkai',
#  'fevralsk',
#  'burnie',
#  'kapuskasing',
#  'karamay',
#  'galveston',
#  'mentok',
#  'kavaratti',
#  'xining',
#  'isangel',
#  'sambava',
#  'hastings',
#  'noumea',
#  'terney',
#  'sao felix do xingu',
#  'whithorn',
#  'taoudenni',
#  'camopi',
#  'romans-sur-isere',
#  'rosario',
#  'ronne',
#  'suyapa de lean',
#  'bagdarin',
#  'mount gambier',
#  'necochea',
#  'lazaro cardenas',
#  'owensboro',
#  'awbari',
#  'kirakira',
#  'beboto',
#  'mahon',
#  'namibe',
#  'gannan',
#  'hammerfest',
#  'kuching',
#  'antofagasta',
#  'kotaparh',
#  'byron bay',
#  'marystown',
#  'aktash',
#  'panaba',
#  'kemerovo',
#  'sarangani',
#  'samusu',
#  'haderslev',
#  'comodoro rivadavia',
#  'dondo',
#  'zhigalovo',
#  'teya',
#  'la cumbre',
#  'tazovskiy',
#  'mezen',
#  'vryburg',
#  'tawkar',
#  'shache',
#  'yarmouth',
#  'ucluelet',
#  'pokhara',
#  'aloleng',
#  'umm kaddadah',
#  'hambantota',
#  'luganville',
#  'berlevag',
#  'ereymentau',
#  'saint-georges',
#  'rio de janeiro',
#  'paracale',
#  'sirjan',
#  'kostomuksha',
#  'chornukhy',
#  'burica',
#  'honiara',
#  'yirol',
#  'sayyan',
#  'praia',
#  'sept-iles',
#  'phonhong',
#  'damghan',
#  'goderich',
#  'kibre mengist',
#  'mullaitivu',
#  'fort madison',
#  'kirishi',
#  'rocha',
#  'egvekinot',
#  'dallas',
#  'basco',
#  'lethem',
#  'collie',
#  'khromtau',
#  'middletown',
#  'the pas',
#  'djibo',
#  'presidencia roque saenz pena',
#  'margate',
#  'sabzevar',
#  'kvitok',
#  'lagoa',
#  'barra',
#  'ouallam',
#  'askiz',
#  'vao',
#  'port macquarie',
#  'caravelas',
#  'west athens',
#  'longyearbyen',
#  'mocambique',
#  'tumannyy',
#  'hakkari',
#  'havre-saint-pierre',
#  'nanortalik',
#  'chazuta',
#  'mananjary',
#  'karaj',
#  'boromo',
#  'vodnyy',
#  'pozo colorado',
#  'aquiraz',
#  'dubna',
#  'binzhou',
#  'muroto',
#  'benghazi',
#  'cumaribo',
#  'sri aman',
#  'makakilo city',
#  'jardinopolis',
#  'tokur',
#  'kuytun',
#  'sofiysk',
#  'aginskoye',
#  'dalen',
#  'alta floresta',
#  'sorong',
#  'odweyne',
#  'atar',
#  'cochabamba',
#  'santa maria',
#  'dutlwe',
#  'palauig',
#  'nelson bay',
#  'ambikapur',
#  'ati',
#  'okato',
#  'torbat-e jam',
#  'karratha',
#  'samarai',
#  'yen bai',
#  'puerto penasco',
#  'betanzos',
#  'jorochito',
#  'utinga',
#  'angul',
#  'nantucket',
#  'vestmanna',
#  'biltine',
#  'galiwinku',
#  'west bay',
#  'zachagansk',
#  'murten',
#  'san buenaventura',
#  'horn lake',
#  'puerto madryn',
#  'san anselmo',
#  'dzhusaly',
#  'elizabeth city',
#  'hearst',
#  'awjilah',
#  'ganserndorf',
#  'rupert',
#  'carbonia',
#  'bani',
#  'mkushi',
#  'voh',
#  'saint-francois',
#  'skjervoy',
#  'qui nhon',
#  'dalbandin',
#  'ganzhou',
#  'coari',
#  'wendo',
#  'tiznit',
#  'hauterive',
#  'sungaipenuh',
#  'longlac',
#  'angoche',
#  'parkes',
#  'cayenne',
#  'bonthe',
#  'besikduzu',
#  'jaragua',
#  'pedernales',
#  'mnogovershinnyy',
#  'mao',
#  'vallenar',
#  'santa marta',
#  'kattivakkam',
#  'sao lourenco do sul',
#  'valparaiso',
#  'albury',
#  'moose factory',
#  'sao francisco',
#  'pedro juan caballero',
#  'bokspits',
#  'lannion',
#  'xingyi',
#  'gorin',
#  'roma',
#  'la serena',
#  'namuac',
#  'nizwa',
#  'maldonado',
#  'fayaoue',
#  'xuddur',
#  'meadow lake',
#  'santa rosalia',
#  'baracoa',
#  'puro',
#  'namie',
#  'uddevalla',
#  'itaguacu',
#  'abaete',
#  'manokwari',
#  'gornopravdinsk',
#  'tilichiki',
#  'malatya',
#  'hrodna',
#  'ca mau',
#  'tacuati',
#  'hammond',
#  'nizhneudinsk',
#  'yertsevo',
#  'dwarka',
#  'jiazi',
#  'ijui',
#  'morant bay',
#  'prabumulih',
#  'tieling',
#  'ternate',
#  'bud',
#  'palana',
#  'biak',
#  'bergen',
#  'eureka',
#  'baruun-urt',
#  'dossor',
#  'boulsa',
#  'khasan',
#  'mende',
#  'sahuaripa',
#  'rio gallegos',
#  'turukhansk',
#  'shasta lake',
#  'manzhouli',
#  'mafinga',
#  'dera bugti',
#  'oga',
#  'yerbogachen',
#  'tombouctou',
#  'waipawa',
#  'pundaguitan',
#  'dongli',
#  'kailua',
#  'makokou',
#  'valer',
#  'bensonville',
#  'adamas',
#  'gabi',
#  'nador',
#  'krasnoarmeyskoye',
#  'chulman',
#  'sao jose da coroa grande',
#  'samalaeulu',
#  'plettenberg bay',
#  'karlstad',
#  'kizema']

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the the citites in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set number and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse teh JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_current = city_weather['weather'][0]['description']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the dity information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_current})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | klaksvik
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | kiunga
# Processing Record 8 of Set 1 | santa cruz del norte
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | udachnyy
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | el tigre
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | ostrovnoy
# Processing Record 17 of Set 1 | manggar
# Processing Record 18 of Set 1 | yagodnoye
# Processing Record 19 of Set 1 | bayan
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | aklavik
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | mankato
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | mussomeli
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | huaicheng
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | zhangye
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | balykshi
# Processing Record 37 of Set 1 | los llanos de aridane
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | kichera
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | englehart
# Processing Record 45 of Set 1 | vila
# Processing Record 46 of Set 1 | paamiut
# Processing Record 47 of Set 1 | poum
# Processing Record 48 of Set 1 | sinnamary
# Processing Record 49 of Set 1 | resistencia
# Processing Record 50 of Set 1 | ballina
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | swellendam
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | tanete
# Processing Record 6 of Set 2 | chokwe
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | port blair
# Processing Record 9 of Set 2 | mildura
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | mehamn
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 2 | saint anthony
# Processing Record 19 of Set 2 | paita
# Processing Record 20 of Set 2 | bosaso
# Processing Record 21 of Set 2 | fuerte olimpo
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | chicama
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | mongo
# Processing Record 28 of Set 2 | port keats
# Processing Record 29 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 30 of Set 2 | huicheng
# Processing Record 31 of Set 2 | tungor
# Processing Record 32 of Set 2 | pangkalanbuun
# Processing Record 33 of Set 2 | hami
# Processing Record 34 of Set 2 | fort nelson
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | saint-joseph
# Processing Record 37 of Set 2 | huaihua
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | arman
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | buta
# Processing Record 44 of Set 2 | sabang
# Processing Record 45 of Set 2 | noyabrsk
# Processing Record 46 of Set 2 | sao filipe
# Processing Record 47 of Set 2 | porto de moz
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | olafsvik
# Processing Record 50 of Set 2 | hamza
# Processing Record 1 of Set 3 | portland
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | gravdal
# Processing Record 5 of Set 3 | kununurra
# Processing Record 6 of Set 3 | cabinda
# Processing Record 7 of Set 3 | lerwick
# Processing Record 8 of Set 3 | port-gentil
# Processing Record 9 of Set 3 | katobu
# Processing Record 10 of Set 3 | morbegno
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | zatyshshya
# Processing Record 14 of Set 3 | lexington
# Processing Record 15 of Set 3 | lata
# Processing Record 16 of Set 3 | kapit
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | garissa
# Processing Record 20 of Set 3 | bati
# Processing Record 21 of Set 3 | ariogala
# Processing Record 22 of Set 3 | guisijan
# Processing Record 23 of Set 3 | grindavik
# Processing Record 24 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 3 | port augusta
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | hirara
# Processing Record 28 of Set 3 | kasama
# Processing Record 29 of Set 3 | qujing
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | saint-pierre
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | mgandu
# Processing Record 35 of Set 3 | haines junction
# Processing Record 36 of Set 3 | beringovskiy
# Processing Record 37 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 3 | coahuayana
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 3 | nenjiang
# Processing Record 42 of Set 3 | caohe
# Processing Record 43 of Set 3 | san pedro
# Processing Record 44 of Set 3 | kutum
# Processing Record 45 of Set 3 | andenes
# Processing Record 46 of Set 3 | rio cuarto
# Processing Record 47 of Set 3 | pevek
# Processing Record 48 of Set 3 | san
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | shellbrook
# Processing Record 3 of Set 4 | yumen
# Processing Record 4 of Set 4 | damaturu
# Processing Record 5 of Set 4 | okha
# Processing Record 6 of Set 4 | nyurba
# Processing Record 7 of Set 4 | vysokogornyy
# Processing Record 8 of Set 4 | oudtshoorn
# Processing Record 9 of Set 4 | inuvik
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | padang
# Processing Record 13 of Set 4 | tura
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | kensington
# Processing Record 19 of Set 4 | buala
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | carnarvon
# Processing Record 22 of Set 4 | black river
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 4 | harper
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | xadani
# City not found. Skipping...
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | andrews
# Processing Record 30 of Set 4 | tucurui
# Processing Record 31 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 4 | airai
# Processing Record 33 of Set 4 | filadelfia
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | grand gaube
# Processing Record 36 of Set 4 | charters towers
# Processing Record 37 of Set 4 | tilzapotla
# Processing Record 38 of Set 4 | ormara
# Processing Record 39 of Set 4 | kloulklubed
# Processing Record 40 of Set 4 | flinders
# Processing Record 41 of Set 4 | carballo
# Processing Record 42 of Set 4 | jiayuguan
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | murgasi
# City not found. Skipping...
# Processing Record 45 of Set 4 | tommot
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | tres arroyos
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | manjacaze
# Processing Record 1 of Set 5 | port hardy
# Processing Record 2 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | kieta
# Processing Record 6 of Set 5 | yar-sale
# Processing Record 7 of Set 5 | savalou
# Processing Record 8 of Set 5 | rodrigues alves
# Processing Record 9 of Set 5 | kargil
# Processing Record 10 of Set 5 | balakhta
# Processing Record 11 of Set 5 | lasa
# Processing Record 12 of Set 5 | acari
# Processing Record 13 of Set 5 | torbay
# Processing Record 14 of Set 5 | mount isa
# Processing Record 15 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 5 | moindou
# Processing Record 17 of Set 5 | olinda
# Processing Record 18 of Set 5 | labrea
# Processing Record 19 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | nizhniy odes
# Processing Record 22 of Set 5 | yeppoon
# Processing Record 23 of Set 5 | avera
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | redmond
# Processing Record 26 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 5 | peruibe
# Processing Record 29 of Set 5 | yuncheng
# Processing Record 30 of Set 5 | cuamba
# Processing Record 31 of Set 5 | port hedland
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | mogadishu
# Processing Record 34 of Set 5 | eyl
# Processing Record 35 of Set 5 | wladyslawowo
# Processing Record 36 of Set 5 | lebork
# Processing Record 37 of Set 5 | luena
# Processing Record 38 of Set 5 | qom
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | esperance
# Processing Record 42 of Set 5 | ushibuka
# Processing Record 43 of Set 5 | pakxan
# Processing Record 44 of Set 5 | abeche
# Processing Record 45 of Set 5 | zavetnoye
# Processing Record 46 of Set 5 | kushiro
# Processing Record 47 of Set 5 | coihaique
# Processing Record 48 of Set 5 | pangnirtung
# Processing Record 49 of Set 5 | srednekolymsk
# Processing Record 50 of Set 5 | kinablangan
# Processing Record 1 of Set 6 | yalchiki
# City not found. Skipping...
# Processing Record 2 of Set 6 | pavlovsk
# Processing Record 3 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 6 | kodiak
# Processing Record 5 of Set 6 | gusau
# Processing Record 6 of Set 6 | igarka
# Processing Record 7 of Set 6 | minab
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | salinopolis
# Processing Record 10 of Set 6 | perth
# Processing Record 11 of Set 6 | fairbanks
# Processing Record 12 of Set 6 | mangaratiba
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | bambanglipuro
# Processing Record 15 of Set 6 | korla
# Processing Record 16 of Set 6 | tigil
# Processing Record 17 of Set 6 | narsaq
# Processing Record 18 of Set 6 | hendek
# Processing Record 19 of Set 6 | adrar
# Processing Record 20 of Set 6 | aswan
# Processing Record 21 of Set 6 | hovd
# Processing Record 22 of Set 6 | lander
# Processing Record 23 of Set 6 | whitehorse
# Processing Record 24 of Set 6 | umm lajj
# Processing Record 25 of Set 6 | port lincoln
# Processing Record 26 of Set 6 | nalut
# Processing Record 27 of Set 6 | neiafu
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | mitsamiouli
# Processing Record 30 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 6 | great bend
# Processing Record 32 of Set 6 | ilulissat
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | inirida
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | kitob
# Processing Record 37 of Set 6 | cidreira
# Processing Record 38 of Set 6 | hobyo
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | meulaboh
# Processing Record 41 of Set 6 | pedasi
# Processing Record 42 of Set 6 | xai-xai
# Processing Record 43 of Set 6 | taltal
# Processing Record 44 of Set 6 | gboko
# Processing Record 45 of Set 6 | sobradinho
# Processing Record 46 of Set 6 | santa isabel do rio negro
# Processing Record 47 of Set 6 | tezu
# Processing Record 48 of Set 6 | tambura
# Processing Record 49 of Set 6 | morgan city
# Processing Record 50 of Set 6 | kyzyl-suu
# Processing Record 1 of Set 7 | jalu
# Processing Record 2 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 7 | chernigovka
# Processing Record 4 of Set 7 | miri
# Processing Record 5 of Set 7 | las cruces
# Processing Record 6 of Set 7 | slonim
# Processing Record 7 of Set 7 | juneau
# Processing Record 8 of Set 7 | mandalgovi
# Processing Record 9 of Set 7 | gorontalo
# Processing Record 10 of Set 7 | vanimo
# Processing Record 11 of Set 7 | ashland
# Processing Record 12 of Set 7 | ryotsu
# Processing Record 13 of Set 7 | makurdi
# Processing Record 14 of Set 7 | sibiti
# Processing Record 15 of Set 7 | san borja
# Processing Record 16 of Set 7 | banda aceh
# Processing Record 17 of Set 7 | hasaki
# Processing Record 18 of Set 7 | bonavista
# Processing Record 19 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 7 | killybegs
# Processing Record 21 of Set 7 | jipijapa
# Processing Record 22 of Set 7 | gigmoto
# Processing Record 23 of Set 7 | kemijarvi
# Processing Record 24 of Set 7 | muros
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | iskateley
# Processing Record 27 of Set 7 | san cristobal
# Processing Record 28 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 7 | iberia
# Processing Record 31 of Set 7 | petatlan
# Processing Record 32 of Set 7 | general pico
# Processing Record 33 of Set 7 | huinan
# Processing Record 34 of Set 7 | lundazi
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | katsuura
# Processing Record 37 of Set 7 | tocopilla
# Processing Record 38 of Set 7 | matamoros
# Processing Record 39 of Set 7 | hamilton
# Processing Record 40 of Set 7 | ahipara
# Processing Record 41 of Set 7 | naze
# Processing Record 42 of Set 7 | manacapuru
# Processing Record 43 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 44 of Set 7 | bethel
# Processing Record 45 of Set 7 | aksarka
# Processing Record 46 of Set 7 | siderno
# Processing Record 47 of Set 7 | ensenada
# Processing Record 48 of Set 7 | nome
# Processing Record 49 of Set 7 | saint george
# Processing Record 50 of Set 7 | kimbe
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | dunedin
# Processing Record 3 of Set 8 | jackson
# Processing Record 4 of Set 8 | vardo
# Processing Record 5 of Set 8 | mangrol
# Processing Record 6 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 8 | bloemhof
# Processing Record 8 of Set 8 | madang
# Processing Record 9 of Set 8 | urumqi
# Processing Record 10 of Set 8 | huarmey
# Processing Record 11 of Set 8 | chute-aux-outardes
# Processing Record 12 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 8 | codrington
# Processing Record 14 of Set 8 | orange cove
# Processing Record 15 of Set 8 | shostka
# Processing Record 16 of Set 8 | la spezia
# Processing Record 17 of Set 8 | san quintin
# Processing Record 18 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 8 | pauini
# Processing Record 20 of Set 8 | souillac
# Processing Record 21 of Set 8 | tomatlan
# Processing Record 22 of Set 8 | bilma
# Processing Record 23 of Set 8 | bursol
# City not found. Skipping...
# Processing Record 24 of Set 8 | xiongzhou
# Processing Record 25 of Set 8 | ashqelon
# Processing Record 26 of Set 8 | qena
# Processing Record 27 of Set 8 | alice springs
# Processing Record 28 of Set 8 | vanavara
# Processing Record 29 of Set 8 | aitape
# Processing Record 30 of Set 8 | pasighat
# Processing Record 31 of Set 8 | bull savanna
# Processing Record 32 of Set 8 | fairhope
# Processing Record 33 of Set 8 | fare
# Processing Record 34 of Set 8 | matara
# Processing Record 35 of Set 8 | belmonte
# Processing Record 36 of Set 8 | merauke
# Processing Record 37 of Set 8 | guerrero negro
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | cumberland
# Processing Record 40 of Set 8 | loa janan
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | viedma
# Processing Record 43 of Set 8 | novaya ladoga
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 46 of Set 8 | kralendijk
# Processing Record 47 of Set 8 | khani
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | mandurah
# Processing Record 50 of Set 8 | aberdeen
# Processing Record 1 of Set 9 | faanui
# Processing Record 2 of Set 9 | champerico
# Processing Record 3 of Set 9 | nahavand
# Processing Record 4 of Set 9 | bulancak
# Processing Record 5 of Set 9 | mizan teferi
# Processing Record 6 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 9 | tralee
# Processing Record 8 of Set 9 | gerede
# Processing Record 9 of Set 9 | zyryanka
# Processing Record 10 of Set 9 | maniitsoq
# Processing Record 11 of Set 9 | arica
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | akonolinga
# Processing Record 14 of Set 9 | verkhnevilyuysk
# Processing Record 15 of Set 9 | iqaluit
# Processing Record 16 of Set 9 | oschatz
# Processing Record 17 of Set 9 | la ronge
# Processing Record 18 of Set 9 | saint-leu
# Processing Record 19 of Set 9 | dosso
# Processing Record 20 of Set 9 | forrest city
# Processing Record 21 of Set 9 | pemberton
# Processing Record 22 of Set 9 | huanuco
# Processing Record 23 of Set 9 | vila franca do campo
# Processing Record 24 of Set 9 | assai
# Processing Record 25 of Set 9 | kurilsk
# Processing Record 26 of Set 9 | lugo
# Processing Record 27 of Set 9 | ixtapa
# Processing Record 28 of Set 9 | alappuzha
# Processing Record 29 of Set 9 | hit
# Processing Record 30 of Set 9 | cap malheureux
# Processing Record 31 of Set 9 | sibu
# Processing Record 32 of Set 9 | husavik
# Processing Record 33 of Set 9 | mirpur sakro
# Processing Record 34 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 9 | westport
# Processing Record 36 of Set 9 | yulara
# Processing Record 37 of Set 9 | carmen
# Processing Record 38 of Set 9 | aken
# Processing Record 39 of Set 9 | quatre cocos
# Processing Record 40 of Set 9 | camacha
# Processing Record 41 of Set 9 | tual
# Processing Record 42 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 9 | conceicao do araguaia
# Processing Record 44 of Set 9 | kaeo
# Processing Record 45 of Set 9 | lephepe
# City not found. Skipping...
# Processing Record 46 of Set 9 | soroti
# Processing Record 47 of Set 9 | omsukchan
# Processing Record 48 of Set 9 | alofi
# Processing Record 49 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 9 | salcininkai
# Processing Record 1 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 10 | burnie
# Processing Record 3 of Set 10 | kapuskasing
# Processing Record 4 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 10 | galveston
# Processing Record 6 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 10 | kavaratti
# Processing Record 8 of Set 10 | xining
# Processing Record 9 of Set 10 | isangel
# Processing Record 10 of Set 10 | sambava
# Processing Record 11 of Set 10 | hastings
# Processing Record 12 of Set 10 | noumea
# Processing Record 13 of Set 10 | terney
# Processing Record 14 of Set 10 | sao felix do xingu
# Processing Record 15 of Set 10 | whithorn
# Processing Record 16 of Set 10 | taoudenni
# Processing Record 17 of Set 10 | camopi
# Processing Record 18 of Set 10 | romans-sur-isere
# Processing Record 19 of Set 10 | rosario
# Processing Record 20 of Set 10 | ronne
# Processing Record 21 of Set 10 | suyapa de lean
# City not found. Skipping...
# Processing Record 22 of Set 10 | bagdarin
# Processing Record 23 of Set 10 | mount gambier
# Processing Record 24 of Set 10 | necochea
# Processing Record 25 of Set 10 | lazaro cardenas
# Processing Record 26 of Set 10 | owensboro
# Processing Record 27 of Set 10 | awbari
# Processing Record 28 of Set 10 | kirakira
# Processing Record 29 of Set 10 | beboto
# Processing Record 30 of Set 10 | mahon
# Processing Record 31 of Set 10 | namibe
# Processing Record 32 of Set 10 | gannan
# Processing Record 33 of Set 10 | hammerfest
# Processing Record 34 of Set 10 | kuching
# Processing Record 35 of Set 10 | antofagasta
# Processing Record 36 of Set 10 | kotaparh
# Processing Record 37 of Set 10 | byron bay
# Processing Record 38 of Set 10 | marystown
# Processing Record 39 of Set 10 | aktash
# Processing Record 40 of Set 10 | panaba
# Processing Record 41 of Set 10 | kemerovo
# Processing Record 42 of Set 10 | sarangani
# Processing Record 43 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 10 | haderslev
# Processing Record 45 of Set 10 | comodoro rivadavia
# Processing Record 46 of Set 10 | dondo
# Processing Record 47 of Set 10 | zhigalovo
# Processing Record 48 of Set 10 | teya
# Processing Record 49 of Set 10 | la cumbre
# Processing Record 50 of Set 10 | tazovskiy
# Processing Record 1 of Set 11 | mezen
# Processing Record 2 of Set 11 | vryburg
# Processing Record 3 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 11 | shache
# Processing Record 5 of Set 11 | yarmouth
# Processing Record 6 of Set 11 | ucluelet
# Processing Record 7 of Set 11 | pokhara
# Processing Record 8 of Set 11 | aloleng
# Processing Record 9 of Set 11 | umm kaddadah
# Processing Record 10 of Set 11 | hambantota
# Processing Record 11 of Set 11 | luganville
# Processing Record 12 of Set 11 | berlevag
# Processing Record 13 of Set 11 | ereymentau
# Processing Record 14 of Set 11 | saint-georges
# Processing Record 15 of Set 11 | rio de janeiro
# Processing Record 16 of Set 11 | paracale
# Processing Record 17 of Set 11 | sirjan
# Processing Record 18 of Set 11 | kostomuksha
# Processing Record 19 of Set 11 | chornukhy
# Processing Record 20 of Set 11 | burica
# City not found. Skipping...
# Processing Record 21 of Set 11 | honiara
# Processing Record 22 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 11 | sayyan
# Processing Record 24 of Set 11 | praia
# Processing Record 25 of Set 11 | sept-iles
# Processing Record 26 of Set 11 | phonhong
# Processing Record 27 of Set 11 | damghan
# Processing Record 28 of Set 11 | goderich
# Processing Record 29 of Set 11 | kibre mengist
# Processing Record 30 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 11 | fort madison
# Processing Record 32 of Set 11 | kirishi
# Processing Record 33 of Set 11 | rocha
# Processing Record 34 of Set 11 | egvekinot
# Processing Record 35 of Set 11 | dallas
# Processing Record 36 of Set 11 | basco
# Processing Record 37 of Set 11 | lethem
# Processing Record 38 of Set 11 | collie
# Processing Record 39 of Set 11 | khromtau
# Processing Record 40 of Set 11 | middletown
# Processing Record 41 of Set 11 | the pas
# Processing Record 42 of Set 11 | djibo
# Processing Record 43 of Set 11 | presidencia roque saenz pena
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | sabzevar
# Processing Record 46 of Set 11 | kvitok
# Processing Record 47 of Set 11 | lagoa
# Processing Record 48 of Set 11 | barra
# Processing Record 49 of Set 11 | ouallam
# Processing Record 50 of Set 11 | askiz
# Processing Record 1 of Set 12 | vao
# Processing Record 2 of Set 12 | port macquarie
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | west athens
# Processing Record 5 of Set 12 | longyearbyen
# Processing Record 6 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 12 | hakkari
# Processing Record 9 of Set 12 | havre-saint-pierre
# Processing Record 10 of Set 12 | nanortalik
# Processing Record 11 of Set 12 | chazuta
# Processing Record 12 of Set 12 | mananjary
# Processing Record 13 of Set 12 | karaj
# Processing Record 14 of Set 12 | boromo
# Processing Record 15 of Set 12 | vodnyy
# Processing Record 16 of Set 12 | pozo colorado
# Processing Record 17 of Set 12 | aquiraz
# Processing Record 18 of Set 12 | dubna
# Processing Record 19 of Set 12 | binzhou
# Processing Record 20 of Set 12 | muroto
# Processing Record 21 of Set 12 | benghazi
# Processing Record 22 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 12 | sri aman
# Processing Record 24 of Set 12 | makakilo city
# Processing Record 25 of Set 12 | jardinopolis
# Processing Record 26 of Set 12 | tokur
# Processing Record 27 of Set 12 | kuytun
# Processing Record 28 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 29 of Set 12 | aginskoye
# Processing Record 30 of Set 12 | dalen
# Processing Record 31 of Set 12 | alta floresta
# Processing Record 32 of Set 12 | sorong
# Processing Record 33 of Set 12 | odweyne
# Processing Record 34 of Set 12 | atar
# Processing Record 35 of Set 12 | cochabamba
# Processing Record 36 of Set 12 | santa maria
# Processing Record 37 of Set 12 | dutlwe
# Processing Record 38 of Set 12 | palauig
# Processing Record 39 of Set 12 | nelson bay
# Processing Record 40 of Set 12 | ambikapur
# Processing Record 41 of Set 12 | ati
# Processing Record 42 of Set 12 | okato
# Processing Record 43 of Set 12 | torbat-e jam
# Processing Record 44 of Set 12 | karratha
# Processing Record 45 of Set 12 | samarai
# Processing Record 46 of Set 12 | yen bai
# Processing Record 47 of Set 12 | puerto penasco
# Processing Record 48 of Set 12 | betanzos
# Processing Record 49 of Set 12 | jorochito
# Processing Record 50 of Set 12 | utinga
# Processing Record 1 of Set 13 | angul
# Processing Record 2 of Set 13 | nantucket
# Processing Record 3 of Set 13 | vestmanna
# Processing Record 4 of Set 13 | biltine
# Processing Record 5 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 13 | west bay
# Processing Record 7 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 8 of Set 13 | murten
# Processing Record 9 of Set 13 | san buenaventura
# Processing Record 10 of Set 13 | horn lake
# Processing Record 11 of Set 13 | puerto madryn
# Processing Record 12 of Set 13 | san anselmo
# Processing Record 13 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 13 | elizabeth city
# Processing Record 15 of Set 13 | hearst
# Processing Record 16 of Set 13 | awjilah
# Processing Record 17 of Set 13 | ganserndorf
# Processing Record 18 of Set 13 | rupert
# Processing Record 19 of Set 13 | carbonia
# Processing Record 20 of Set 13 | bani
# Processing Record 21 of Set 13 | mkushi
# Processing Record 22 of Set 13 | voh
# Processing Record 23 of Set 13 | saint-francois
# Processing Record 24 of Set 13 | skjervoy
# Processing Record 25 of Set 13 | qui nhon
# Processing Record 26 of Set 13 | dalbandin
# Processing Record 27 of Set 13 | ganzhou
# Processing Record 28 of Set 13 | coari
# Processing Record 29 of Set 13 | wendo
# Processing Record 30 of Set 13 | tiznit
# Processing Record 31 of Set 13 | hauterive
# Processing Record 32 of Set 13 | sungaipenuh
# Processing Record 33 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 13 | angoche
# Processing Record 35 of Set 13 | parkes
# Processing Record 36 of Set 13 | cayenne
# Processing Record 37 of Set 13 | bonthe
# Processing Record 38 of Set 13 | besikduzu
# Processing Record 39 of Set 13 | jaragua
# Processing Record 40 of Set 13 | pedernales
# Processing Record 41 of Set 13 | mnogovershinnyy
# Processing Record 42 of Set 13 | mao
# Processing Record 43 of Set 13 | vallenar
# Processing Record 44 of Set 13 | santa marta
# Processing Record 45 of Set 13 | kattivakkam
# Processing Record 46 of Set 13 | sao lourenco do sul
# Processing Record 47 of Set 13 | valparaiso
# Processing Record 48 of Set 13 | albury
# Processing Record 49 of Set 13 | moose factory
# Processing Record 50 of Set 13 | sao francisco
# Processing Record 1 of Set 14 | pedro juan caballero
# Processing Record 2 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 3 of Set 14 | lannion
# Processing Record 4 of Set 14 | xingyi
# Processing Record 5 of Set 14 | gorin
# Processing Record 6 of Set 14 | roma
# Processing Record 7 of Set 14 | la serena
# Processing Record 8 of Set 14 | namuac
# Processing Record 9 of Set 14 | nizwa
# Processing Record 10 of Set 14 | maldonado
# Processing Record 11 of Set 14 | fayaoue
# Processing Record 12 of Set 14 | xuddur
# Processing Record 13 of Set 14 | meadow lake
# Processing Record 14 of Set 14 | santa rosalia
# Processing Record 15 of Set 14 | baracoa
# Processing Record 16 of Set 14 | puro
# Processing Record 17 of Set 14 | namie
# Processing Record 18 of Set 14 | uddevalla
# Processing Record 19 of Set 14 | itaguacu
# Processing Record 20 of Set 14 | abaete
# Processing Record 21 of Set 14 | manokwari
# Processing Record 22 of Set 14 | gornopravdinsk
# Processing Record 23 of Set 14 | tilichiki
# Processing Record 24 of Set 14 | malatya
# Processing Record 25 of Set 14 | hrodna
# Processing Record 26 of Set 14 | ca mau
# Processing Record 27 of Set 14 | tacuati
# Processing Record 28 of Set 14 | hammond
# Processing Record 29 of Set 14 | nizhneudinsk
# Processing Record 30 of Set 14 | yertsevo
# Processing Record 31 of Set 14 | dwarka
# Processing Record 32 of Set 14 | jiazi
# Processing Record 33 of Set 14 | ijui
# Processing Record 34 of Set 14 | morant bay
# Processing Record 35 of Set 14 | prabumulih
# Processing Record 36 of Set 14 | tieling
# Processing Record 37 of Set 14 | ternate
# Processing Record 38 of Set 14 | bud
# Processing Record 39 of Set 14 | palana
# Processing Record 40 of Set 14 | biak
# Processing Record 41 of Set 14 | bergen
# Processing Record 42 of Set 14 | eureka
# Processing Record 43 of Set 14 | baruun-urt
# Processing Record 44 of Set 14 | dossor
# Processing Record 45 of Set 14 | boulsa
# Processing Record 46 of Set 14 | khasan
# Processing Record 47 of Set 14 | mende
# Processing Record 48 of Set 14 | sahuaripa
# Processing Record 49 of Set 14 | rio gallegos
# Processing Record 50 of Set 14 | turukhansk
# Processing Record 1 of Set 15 | shasta lake
# Processing Record 2 of Set 15 | manzhouli
# Processing Record 3 of Set 15 | mafinga
# Processing Record 4 of Set 15 | dera bugti
# Processing Record 5 of Set 15 | oga
# Processing Record 6 of Set 15 | yerbogachen
# Processing Record 7 of Set 15 | tombouctou
# Processing Record 8 of Set 15 | waipawa
# Processing Record 9 of Set 15 | pundaguitan
# Processing Record 10 of Set 15 | dongli
# Processing Record 11 of Set 15 | kailua
# Processing Record 12 of Set 15 | makokou
# Processing Record 13 of Set 15 | valer
# Processing Record 14 of Set 15 | bensonville
# Processing Record 15 of Set 15 | adamas
# Processing Record 16 of Set 15 | gabi
# Processing Record 17 of Set 15 | nador
# Processing Record 18 of Set 15 | krasnoarmeyskoye
# Processing Record 19 of Set 15 | chulman
# Processing Record 20 of Set 15 | sao jose da coroa grande
# Processing Record 21 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 15 | plettenberg bay
# Processing Record 23 of Set 15 | karlstad
# Processing Record 24 of Set 15 | kizema
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Atuona  -9.8000 -139.0333     78.04        75          51       15.79
# 1    Jamestown  42.0970  -79.2353     76.59        50          40       15.99
# 2  Provideniya  64.3833 -173.3000     42.67        80          99       10.54
# 3     Klaksvik  62.2266   -6.5890     50.92        80          89        6.44
# 4     Hermanus -34.4187   19.2345     57.90        87          99        8.30
#
#   Country Current Description
# 0      PF       broken clouds
# 1      US    scattered clouds
# 2      RU          light rain
# 3      FO     overcast clouds
# 4      ZA     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
