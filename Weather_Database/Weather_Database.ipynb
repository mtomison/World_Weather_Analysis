# %%
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import json
from config import weather_api_key
import requests
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations:
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180,high=180, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a ist for holding the cities
cities = []
city_data = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to teh cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %%
cities
# Out:
# ['bethel',
#  'ushuaia',
#  'esperance',
#  'bredasdorp',
#  'havoysund',
#  'atuona',
#  'mataura',
#  'nishihara',
#  'new norfolk',
#  'luganville',
#  'rikitea',
#  'baykit',
#  'tondano',
#  'klaksvik',
#  'nome',
#  'hohhot',
#  'mar del plata',
#  'tuktoyaktuk',
#  'ilulissat',
#  'vaini',
#  'vardo',
#  'whitehorse',
#  'jiangyou',
#  'pacific grove',
#  'aleksandrov gay',
#  'port elizabeth',
#  'kosa',
#  'the valley',
#  'tecoanapa',
#  'palmer',
#  'albany',
#  'mexico',
#  'nanortalik',
#  'illoqqortoormiut',
#  'severo-kurilsk',
#  'busselton',
#  'dwarka',
#  'paamiut',
#  'laguna',
#  'canutama',
#  'thunder bay',
#  'sao joao da barra',
#  'jamestown',
#  'rocha',
#  'ponta do sol',
#  'thompson',
#  'salalah',
#  'ancud',
#  'saiha',
#  'bengkulu',
#  'leh',
#  'muyezerskiy',
#  'sorland',
#  'padang',
#  'hilo',
#  'combita',
#  'iqaluit',
#  'hobart',
#  'nikolayevsk-na-amure',
#  'grand river south east',
#  'nizhneyansk',
#  'lebu',
#  'barrow',
#  'khani',
#  'narsaq',
#  'port alfred',
#  'imbituba',
#  'airai',
#  'prince rupert',
#  'zachagansk',
#  'qaqortoq',
#  'shimoda',
#  'kavaratti',
#  'namibe',
#  'kaitangata',
#  'taolanaro',
#  'yuzhno-yeniseyskiy',
#  'beringovskiy',
#  'kieta',
#  'puerto ayora',
#  'balkhash',
#  'kapaa',
#  'tasiilaq',
#  'upernavik',
#  'cape town',
#  'qaanaaq',
#  'la ronge',
#  'husavik',
#  'vila velha',
#  'cidreira',
#  'chapais',
#  'khatanga',
#  'hanna',
#  'souillac',
#  'mahebourg',
#  'katsuura',
#  'tsihombe',
#  'bardiyah',
#  'comodoro rivadavia',
#  'kavieng',
#  'broken hill',
#  'pevek',
#  'lorengau',
#  'college',
#  'owando',
#  'bumba',
#  'nabire',
#  'hamilton',
#  'louisbourg',
#  'aimores',
#  'butaritari',
#  'toliary',
#  'tooele',
#  'lata',
#  'sentyabrskiy',
#  'port augusta',
#  'carnarvon',
#  'belushya guba',
#  'cap malheureux',
#  'hithadhoo',
#  'mastic beach',
#  'sitka',
#  'tiksi',
#  'isla aguada',
#  'eydhafushi',
#  'provideniya',
#  'punta arenas',
#  'hermanus',
#  'bluff',
#  'dikson',
#  'tuatapere',
#  'cayenne',
#  'barcelona',
#  'saleaula',
#  'yumen',
#  'pangnirtung',
#  'ahipara',
#  'buraydah',
#  'hasaki',
#  'ust-omchug',
#  'stornoway',
#  'east london',
#  'formoso do araguaia',
#  'viligili',
#  'caxito',
#  'kant',
#  'lompoc',
#  'melbourne',
#  'bambous virieux',
#  'vrangel',
#  'kruisfontein',
#  'bilibino',
#  'champerico',
#  'chokurdakh',
#  'dingle',
#  'san cristobal',
#  'kabalo',
#  'biak',
#  'saint-francois',
#  'mochudi',
#  'atar',
#  'mocuba',
#  'cherskiy',
#  'qeshm',
#  'bismil',
#  'pisco',
#  'lavrentiya',
#  'morant bay',
#  'saint-philippe',
#  'aguada de pasajeros',
#  'amderma',
#  'maneadero',
#  'eenhana',
#  'castro',
#  'chara',
#  'belyy yar',
#  'santa ana',
#  'visby',
#  'kashi',
#  'attur',
#  'fomboni',
#  'uk',
#  'bay roberts',
#  'vostok',
#  'manga',
#  'rio grande',
#  'chuy',
#  'labuhan',
#  'saskylakh',
#  'makat',
#  'luderitz',
#  'tweed',
#  'avarua',
#  'mujiayingzi',
#  'itarema',
#  'port hardy',
#  'port lincoln',
#  'arraial do cabo',
#  'kahului',
#  'ormond beach',
#  'zaysan',
#  'mahon',
#  'gharo',
#  'coahuayana',
#  'pouebo',
#  'asau',
#  'mount gambier',
#  'beacon',
#  'vzmorye',
#  'zhezkazgan',
#  'erdenet',
#  'balakhta',
#  'masumbwe',
#  'kasempa',
#  'fredericton',
#  'waingapu',
#  'mitu',
#  'ukiah',
#  'jumla',
#  'kisangani',
#  'kabardinka',
#  'portland',
#  'barentsburg',
#  'jiayuguan',
#  'half moon bay',
#  'mys shmidta',
#  'tilichiki',
#  'sonamura',
#  'guerrero negro',
#  'bur gabo',
#  'blantyre',
#  'berlevag',
#  'coffs harbour',
#  'talara',
#  'brae',
#  'labutta',
#  'caravelas',
#  'sao filipe',
#  'viedma',
#  'genthin',
#  'coquimbo',
#  'ovre ardal',
#  'paignton',
#  'agropoli',
#  'kodinsk',
#  'vanimo',
#  'faanui',
#  'kuala terengganu',
#  'korla',
#  'kodiak',
#  'saint george',
#  'kurilsk',
#  'clyde river',
#  'lufilufi',
#  'penzance',
#  'dubenskiy',
#  'tashla',
#  'fethiye',
#  'korzhevskiy',
#  'nikolskoye',
#  'aksu',
#  'rundu',
#  'marawi',
#  'sobolevo',
#  'igarka',
#  'georgetown',
#  'booue',
#  'port moresby',
#  'ko samui',
#  'prachuap khiri khan',
#  'san patricio',
#  'aflu',
#  'hobyo',
#  'tabou',
#  'niono',
#  'srednekolymsk',
#  'xuddur',
#  'umzimvubu',
#  'goderich',
#  'mayumba',
#  'rio gallegos',
#  'bud',
#  'reefton',
#  'mecca',
#  'gambela',
#  'casper',
#  'peace river',
#  'tucurui',
#  'cabo san lucas',
#  'asyut',
#  'beidao',
#  'palabuhanratu',
#  'hopewell',
#  'skage',
#  'miguel hidalgo',
#  'richards bay',
#  'surt',
#  'golden',
#  'lagoa',
#  'codrington',
#  'san mateo del mar',
#  'aranos',
#  'galiwinku',
#  'luwuk',
#  'adrar',
#  'mayo',
#  'mallama',
#  'yulara',
#  'saint-georges',
#  'sao luiz gonzaga',
#  'olafsvik',
#  'sirna',
#  'aklavik',
#  'tumannyy',
#  'honiara',
#  'victoria',
#  'varzelandia',
#  'bonthe',
#  'san-pedro',
#  'poshekhonye',
#  'ankazoabo',
#  'wanning',
#  'grindavik',
#  'duluth',
#  'santa lucia',
#  'saquarema',
#  'yellowknife',
#  'russell',
#  'portoferraio',
#  'riyadh',
#  'jinchengjiang',
#  'longyearbyen',
#  'kluczbork',
#  'palmerston',
#  'vila franca do campo',
#  'vestmannaeyjar',
#  'auriflama',
#  'looc',
#  'qasigiannguit',
#  'anantnag',
#  'methoni',
#  'bera',
#  'barmer',
#  'mehamn',
#  'nkhotakota',
#  'haverfordwest',
#  'vanderhoof',
#  'murray bridge',
#  'conceicao da barra',
#  'karaton',
#  'port keats',
#  'basco',
#  'awjilah',
#  'saldanha',
#  'torbay',
#  'kysyl-syr',
#  'manokwari',
#  'cranbrook',
#  'laukaa',
#  'auki',
#  'fortuna',
#  'tessaoua',
#  'genhe',
#  'yaan',
#  'jiwani',
#  'norman wells',
#  'chumikan',
#  'karaul',
#  'antigonish',
#  'broome',
#  'atambua',
#  'harrisburg',
#  'manyana',
#  'lasa',
#  'ribeirao bonito',
#  'ambon',
#  'shostka',
#  'weligama',
#  'tzaneen',
#  'wuwei',
#  'opuwo',
#  'vaitupu',
#  'chapada dos guimaraes',
#  'deputatskiy',
#  'marzuq',
#  'rancho palos verdes',
#  'lipin bor',
#  'bastia',
#  'poum',
#  'verkhneuralsk',
#  'koslan',
#  'juodupe',
#  'pangody',
#  'ucluelet',
#  'kirakira',
#  'katsina',
#  'catamarca',
#  'barraute',
#  'surami',
#  'kem',
#  'los llanos de aridane',
#  'bristol',
#  'sept-iles',
#  'zhanaozen',
#  'ribeira grande',
#  'vao',
#  'saint anthony',
#  'hvammstangi',
#  'mendota',
#  'yenagoa',
#  'kununurra',
#  'porto santo',
#  'toungoo',
#  'lolua',
#  'wilmington',
#  'warri',
#  'araguaina',
#  'gibara',
#  'bonnyville',
#  'cockburn town',
#  'yarmouth',
#  'paramonga',
#  'lerwick',
#  'corpus christi',
#  'krasnoselkup',
#  'lawrenceburg',
#  'polson',
#  'verkhnevilyuysk',
#  'sorata',
#  'kenai',
#  'khonuu',
#  'nakusp',
#  'yecuatla',
#  'tarakan',
#  'peru',
#  'porkhov',
#  'hofn',
#  'mala',
#  'sioux lookout',
#  'casa nova',
#  'terney',
#  'kudahuvadhoo',
#  'yithion',
#  'peniche',
#  'leningradskiy',
#  'palu',
#  'archena',
#  'ituni',
#  'xining',
#  'attawapiskat',
#  'shumskiy',
#  'thinadhoo',
#  'bournemouth',
#  'te anau',
#  'ibb',
#  'cheuskiny',
#  'ushtobe',
#  'walvis bay',
#  'balabac',
#  'westport',
#  'basugaon',
#  'faya',
#  'pasinler',
#  'amahai',
#  'raudeberg',
#  'ewa beach',
#  'mount isa',
#  'altay',
#  'roald',
#  'srandakan',
#  'constitucion',
#  'novosergiyevka',
#  'chaihe',
#  'bella union',
#  'taos',
#  'savalou',
#  'belmonte',
#  'alice springs',
#  'bemidji',
#  'solovetskiy',
#  'buckeye',
#  'san quintin',
#  'kazalinsk',
#  'cumaribo',
#  'warrington',
#  'quatre cocos',
#  'bandarbeyla',
#  'tokzar',
#  'shingu',
#  'temnikov',
#  'rapid valley',
#  'grand baie',
#  'inhambane',
#  'bac lieu',
#  'iacu',
#  'valdivia',
#  'nyurba',
#  'coihaique',
#  'port-gentil',
#  'holme',
#  'saint-augustin',
#  'yar-sale',
#  'chino valley',
#  'gobabis',
#  'pringsewu',
#  'rawlins',
#  'ayan',
#  'smolenka',
#  'ballarat',
#  'ocotepec',
#  'fort saint john',
#  'tlahualilo',
#  'maldonado',
#  'tongliao',
#  'beloha',
#  'guajara-mirim',
#  'madimba',
#  'sucre',
#  'dongsheng',
#  'madang',
#  'channel-port aux basques',
#  'maumere',
#  'cascais',
#  'fairbanks',
#  'riberalta',
#  'udachnyy',
#  'alihe',
#  'vangaindrano',
#  'bahile',
#  'sao gabriel da cachoeira',
#  'barbar',
#  'san carlos de bariloche',
#  'vestmanna',
#  'iki-burul',
#  'vidim',
#  'arriaga',
#  'tigil',
#  'satitoa',
#  'rawson',
#  'goure',
#  'bambanglipuro',
#  'laharpur',
#  'odienne',
#  'touros',
#  'florianopolis',
#  'hervey bay',
#  'dunedin',
#  'lubbock',
#  'port blair',
#  'namtsy',
#  'chulumani',
#  'erenhot',
#  'tignere',
#  'taoudenni',
#  'skaudvile',
#  'baruun-urt',
#  'tamale',
#  'sambava',
#  'nhulunbuy',
#  'vajszlo',
#  'moron',
#  'takoradi',
#  'nizhnevartovsk',
#  'bolobo',
#  'dzhebariki-khaya',
#  'palafrugell',
#  'matelandia',
#  'brandon',
#  'nioro',
#  'ahar',
#  'gerash',
#  'malartic',
#  'marietta',
#  'axim',
#  'bhag',
#  'isangel',
#  'aswan',
#  'strezhevoy',
#  'anadyr',
#  'buenos aires',
#  'lingao',
#  'gidole',
#  'huilong',
#  'anloga',
#  'mareeba',
#  'itaituba',
#  'honningsvag',
#  'warqla',
#  'kholtoson',
#  'taunggyi',
#  'fano',
#  'sucua',
#  'maralal',
#  'lahan',
#  'tighina',
#  'verdun',
#  'ntchisi',
#  'jinchang',
#  'taltal',
#  'mushie',
#  'kulebaki',
#  'halalo',
#  'gornyak',
#  'berlin',
#  'george town',
#  'savannah bight',
#  'ixtapa',
#  'geraldton',
#  'lalomanu',
#  'grand gaube',
#  'lixourion',
#  'williams lake',
#  'vila',
#  'rungata',
#  'waddan',
#  'kiunga',
#  'sinnamary',
#  'erzin',
#  'naze',
#  'samalaeulu',
#  'sorel',
#  'outlook',
#  'port hawkesbury',
#  'seidu',
#  'zhengjiatun',
#  'fort morgan',
#  'porto torres',
#  'taybad',
#  'socorro',
#  'baghmara',
#  'kontagora',
#  'akdepe',
#  'ust-kuyga',
#  'leninskoye',
#  'kirovskiy',
#  'guayape',
#  'bulawayo',
#  'aiquile',
#  'marcona',
#  'sur',
#  'kaduna',
#  'malanje',
#  'tawnat',
#  'gubkinskiy',
#  'horta',
#  'malibu',
#  'maceio',
#  'saint-louis',
#  'santiago del estero',
#  'samusu',
#  'noumea',
#  'inverness',
#  'benguela',
#  'kachikau',
#  'chengde',
#  'madison',
#  'hovd',
#  'eureka',
#  'kattivakkam',
#  'flin flon',
#  'uyuni',
#  'umm lajj',
#  'batagay',
#  'ojinaga',
#  'mirandela',
#  'kismayo',
#  'agde',
#  'orissaare',
#  'codajas',
#  'micheweni',
#  'scarborough',
#  'kaseda',
#  'ossora',
#  'pokhara',
#  'ereymentau',
#  'bled',
#  'garm',
#  'bad doberan',
#  'sorong',
#  'bilma',
#  'gopalpur',
#  'tomball',
#  'kendari',
#  'eyl',
#  'jiaozuo',
#  'zlatoustovsk',
#  'sibu',
#  'boyolangu',
#  'huangchuan',
#  'oktyabrskoye',
#  'talcahuano',
#  'taburi',
#  'zhaotong',
#  'lantawan',
#  'preston',
#  'corinto',
#  'kalamb',
#  'ponta delgada',
#  'henties bay',
#  'horodnytsya',
#  'manavalakurichi',
#  'rovaniemi',
#  'tarko-sale',
#  'morondava',
#  'halifax',
#  'esfarayen',
#  'yanan',
#  'morehead',
#  'el tocuyo',
#  'pimentel',
#  'lysyye gory',
#  'miramar',
#  'pochutla',
#  'kutum',
#  'sao felix do xingu',
#  'sterling',
#  'banjar',
#  'mullaitivu',
#  'agogo',
#  'kamiiso',
#  'alugan',
#  'alta floresta',
#  'edd',
#  'shangzhi',
#  'uige',
#  'fort madison',
#  'hambantota',
#  'hunza',
#  'mayor pablo lagerenza',
#  'putina',
#  'santiago',
#  'rudnogorsk',
#  'bolsheustikinskoye',
#  'hudiksvall',
#  'saryshagan',
#  'izberbash',
#  'kangaatsiaq',
#  'northam',
#  'shache',
#  'antalya']

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the the citites in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set number and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse teh JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        #city_current = city_weather['weather'][0]['description']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the dity information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": ""})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | srednekolymsk
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | colares
# Processing Record 4 of Set 1 | inhambane
# Processing Record 5 of Set 1 | matamba
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | alofi
# Processing Record 8 of Set 1 | cooma
# Processing Record 9 of Set 1 | bosobolo
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | san jose
# Processing Record 15 of Set 1 | whitehorse
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | krasnoyarsk
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | redlands
# Processing Record 22 of Set 1 | guanica
# Processing Record 23 of Set 1 | acapulco
# Processing Record 24 of Set 1 | qidong
# Processing Record 25 of Set 1 | sao filipe
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | ravar
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | yerani
# City not found. Skipping...
# Processing Record 30 of Set 1 | yar-sale
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | kavaratti
# Processing Record 34 of Set 1 | kysyl-syr
# Processing Record 35 of Set 1 | tautira
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | kokopo
# Processing Record 39 of Set 1 | catarman
# Processing Record 40 of Set 1 | mitu
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | iquique
# Processing Record 43 of Set 1 | dori
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | vallenar
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | teguldet
# Processing Record 2 of Set 2 | dargaville
# Processing Record 3 of Set 2 | egvekinot
# Processing Record 4 of Set 2 | vaasa
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | gurupi
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | kijini
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | touros
# Processing Record 12 of Set 2 | kruisfontein
# Processing Record 13 of Set 2 | tarko-sale
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | puerto escondido
# Processing Record 17 of Set 2 | jijiga
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | seymchan
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | teya
# Processing Record 23 of Set 2 | kulhudhuffushi
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | seoul
# Processing Record 26 of Set 2 | itoman
# Processing Record 27 of Set 2 | tornio
# Processing Record 28 of Set 2 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | moose factory
# Processing Record 32 of Set 2 | dryden
# Processing Record 33 of Set 2 | dzhebariki-khaya
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | katobu
# Processing Record 36 of Set 2 | narsaq
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | henties bay
# Processing Record 39 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 2 | guarapari
# Processing Record 41 of Set 2 | vardo
# Processing Record 42 of Set 2 | port lincoln
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | weiser
# Processing Record 48 of Set 2 | caruray
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | zhigalovo
# Processing Record 2 of Set 3 | antofagasta
# Processing Record 3 of Set 3 | lake havasu city
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | key west
# Processing Record 6 of Set 3 | buin
# Processing Record 7 of Set 3 | sola
# Processing Record 8 of Set 3 | umm lajj
# Processing Record 9 of Set 3 | kukuna
# Processing Record 10 of Set 3 | dakoro
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | payo
# Processing Record 13 of Set 3 | chunoyar
# Processing Record 14 of Set 3 | berlevag
# Processing Record 15 of Set 3 | nikko
# Processing Record 16 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 17 of Set 3 | port macquarie
# Processing Record 18 of Set 3 | lugo
# Processing Record 19 of Set 3 | trofors
# Processing Record 20 of Set 3 | road town
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | meulaboh
# Processing Record 23 of Set 3 | port blair
# Processing Record 24 of Set 3 | nabire
# Processing Record 25 of Set 3 | puerto cabezas
# Processing Record 26 of Set 3 | margate
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | peniche
# Processing Record 30 of Set 3 | jamestown
# Processing Record 31 of Set 3 | svobodnyy
# Processing Record 32 of Set 3 | san bartolome de tirajana
# Processing Record 33 of Set 3 | svetlyy
# Processing Record 34 of Set 3 | dingle
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | bonito
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | greenville
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | cape town
# Processing Record 43 of Set 3 | rio cuarto
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | linguere
# Processing Record 47 of Set 3 | te anau
# Processing Record 48 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 49 of Set 3 | gualaquiza
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | paragominas
# Processing Record 3 of Set 4 | tiznit
# Processing Record 4 of Set 4 | jian
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | tommot
# Processing Record 8 of Set 4 | namibe
# Processing Record 9 of Set 4 | hashtgerd
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | tuatapere
# Processing Record 12 of Set 4 | mamakan
# Processing Record 13 of Set 4 | kuhestan
# City not found. Skipping...
# Processing Record 14 of Set 4 | sistranda
# Processing Record 15 of Set 4 | gondanglegi
# Processing Record 16 of Set 4 | kloulklubed
# Processing Record 17 of Set 4 | mayya
# Processing Record 18 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 4 | zhigansk
# Processing Record 20 of Set 4 | san cristobal
# Processing Record 21 of Set 4 | angoche
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | haines junction
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | zabol
# Processing Record 26 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 4 | sapouy
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | charters towers
# Processing Record 31 of Set 4 | hilo
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | korla
# Processing Record 36 of Set 4 | pagudpud
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | suluq
# Processing Record 39 of Set 4 | kambove
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | vila franca do campo
# Processing Record 42 of Set 4 | veraval
# Processing Record 43 of Set 4 | hermanus
# Processing Record 44 of Set 4 | bontang
# Processing Record 45 of Set 4 | okha
# Processing Record 46 of Set 4 | obidos
# Processing Record 47 of Set 4 | najran
# Processing Record 48 of Set 4 | altay
# Processing Record 49 of Set 4 | kiruna
# Processing Record 50 of Set 4 | kurumkan
# Processing Record 1 of Set 5 | saint-augustin
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | robat karim
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | yagodnoye
# Processing Record 7 of Set 5 | heinola
# Processing Record 8 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 5 | moron
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | vostok
# Processing Record 13 of Set 5 | ponta delgada
# Processing Record 14 of Set 5 | rundu
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | chokurdakh
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | baruun-urt
# Processing Record 21 of Set 5 | christchurch
# Processing Record 22 of Set 5 | santo antonio do leverger
# Processing Record 23 of Set 5 | komsomolskiy
# Processing Record 24 of Set 5 | porto novo
# Processing Record 25 of Set 5 | san quintin
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 5 | kutum
# Processing Record 30 of Set 5 | poum
# Processing Record 31 of Set 5 | monrovia
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | erzin
# Processing Record 34 of Set 5 | svidnik
# Processing Record 35 of Set 5 | hobyo
# Processing Record 36 of Set 5 | hay river
# Processing Record 37 of Set 5 | chokwe
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | pecos
# Processing Record 40 of Set 5 | mount gambier
# Processing Record 41 of Set 5 | denpasar
# Processing Record 42 of Set 5 | geraldton
# Processing Record 43 of Set 5 | wanaka
# Processing Record 44 of Set 5 | kelapa sawit
# Processing Record 45 of Set 5 | hervey bay
# Processing Record 46 of Set 5 | armidale
# Processing Record 47 of Set 5 | burica
# City not found. Skipping...
# Processing Record 48 of Set 5 | trapani
# Processing Record 49 of Set 5 | isangel
# Processing Record 50 of Set 5 | marbella
# Processing Record 1 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 6 | ternate
# Processing Record 3 of Set 6 | jalu
# Processing Record 4 of Set 6 | tonekabon
# Processing Record 5 of Set 6 | tiarei
# Processing Record 6 of Set 6 | solnechnyy
# Processing Record 7 of Set 6 | cabedelo
# Processing Record 8 of Set 6 | sitka
# Processing Record 9 of Set 6 | nguruka
# Processing Record 10 of Set 6 | batagay-alyta
# Processing Record 11 of Set 6 | dholka
# Processing Record 12 of Set 6 | roald
# Processing Record 13 of Set 6 | ankang
# Processing Record 14 of Set 6 | santa eulalia
# Processing Record 15 of Set 6 | zholymbet
# Processing Record 16 of Set 6 | archidona
# Processing Record 17 of Set 6 | vestmannaeyjar
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | jvari
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | ginir
# Processing Record 22 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 6 | springfield
# Processing Record 24 of Set 6 | senneterre
# Processing Record 25 of Set 6 | kobayashi
# Processing Record 26 of Set 6 | portland
# Processing Record 27 of Set 6 | opuwo
# Processing Record 28 of Set 6 | bad frankenhausen
# Processing Record 29 of Set 6 | coari
# Processing Record 30 of Set 6 | sacramento
# Processing Record 31 of Set 6 | pathein
# Processing Record 32 of Set 6 | lagoa
# Processing Record 33 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 6 | kailua
# Processing Record 35 of Set 6 | port shepstone
# Processing Record 36 of Set 6 | consolacion del sur
# Processing Record 37 of Set 6 | praia da vitoria
# Processing Record 38 of Set 6 | nardaran
# Processing Record 39 of Set 6 | kelowna
# Processing Record 40 of Set 6 | bubaque
# Processing Record 41 of Set 6 | hofn
# Processing Record 42 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 6 | kayankulam
# Processing Record 44 of Set 6 | debre tabor
# Processing Record 45 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 6 | hambantota
# Processing Record 47 of Set 6 | cockburn town
# Processing Record 48 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 6 | griffith
# Processing Record 50 of Set 6 | havoysund
# Processing Record 1 of Set 7 | mersing
# Processing Record 2 of Set 7 | aksarka
# Processing Record 3 of Set 7 | shanhetun
# Processing Record 4 of Set 7 | evensk
# Processing Record 5 of Set 7 | shenzhen
# Processing Record 6 of Set 7 | tuktoyaktuk
# Processing Record 7 of Set 7 | marienburg
# Processing Record 8 of Set 7 | zaragoza
# Processing Record 9 of Set 7 | alexandria
# Processing Record 10 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 7 | rawson
# Processing Record 12 of Set 7 | mendi
# Processing Record 13 of Set 7 | sagaing
# Processing Record 14 of Set 7 | concordia
# Processing Record 15 of Set 7 | norman wells
# Processing Record 16 of Set 7 | gizo
# Processing Record 17 of Set 7 | taksimo
# Processing Record 18 of Set 7 | anadyr
# Processing Record 19 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 7 | dovers
# Processing Record 21 of Set 7 | sokoni
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | ribeira grande
# Processing Record 24 of Set 7 | pangnirtung
# Processing Record 25 of Set 7 | panguipulli
# Processing Record 26 of Set 7 | verkhoyansk
# Processing Record 27 of Set 7 | saint-joseph
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | ordynskoye
# Processing Record 30 of Set 7 | grand gaube
# Processing Record 31 of Set 7 | jacareacanga
# Processing Record 32 of Set 7 | murupara
# Processing Record 33 of Set 7 | silver city
# Processing Record 34 of Set 7 | astoria
# Processing Record 35 of Set 7 | milton
# Processing Record 36 of Set 7 | talnakh
# Processing Record 37 of Set 7 | raudeberg
# Processing Record 38 of Set 7 | biloxi
# Processing Record 39 of Set 7 | mar del plata
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | ewo
# Processing Record 42 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 43 of Set 7 | ossora
# Processing Record 44 of Set 7 | morgan city
# Processing Record 45 of Set 7 | fortuna
# Processing Record 46 of Set 7 | souillac
# Processing Record 47 of Set 7 | omboue
# Processing Record 48 of Set 7 | kanniyakumari
# Processing Record 49 of Set 7 | chesterville
# Processing Record 50 of Set 7 | samarai
# Processing Record 1 of Set 8 | tres lagoas
# Processing Record 2 of Set 8 | ponta do sol
# Processing Record 3 of Set 8 | otradnoye
# Processing Record 4 of Set 8 | lahij
# Processing Record 5 of Set 8 | wanning
# Processing Record 6 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 8 | lodwar
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | saint-louis
# Processing Record 10 of Set 8 | guebwiller
# Processing Record 11 of Set 8 | zeya
# Processing Record 12 of Set 8 | manono
# Processing Record 13 of Set 8 | nouadhibou
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 8 | honolulu
# Processing Record 17 of Set 8 | victoria
# Processing Record 18 of Set 8 | ndola
# Processing Record 19 of Set 8 | zhangjiakou
# Processing Record 20 of Set 8 | castro
# Processing Record 21 of Set 8 | krasnyy chikoy
# Processing Record 22 of Set 8 | conakry
# Processing Record 23 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 8 | katsuura
# Processing Record 25 of Set 8 | trinidad
# Processing Record 26 of Set 8 | alingsas
# Processing Record 27 of Set 8 | leghorn
# City not found. Skipping...
# Processing Record 28 of Set 8 | dickinson
# Processing Record 29 of Set 8 | nizhnyaya poyma
# Processing Record 30 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 8 | bismarck
# Processing Record 32 of Set 8 | aklavik
# Processing Record 33 of Set 8 | ambilobe
# Processing Record 34 of Set 8 | trenggalek
# Processing Record 35 of Set 8 | namatanai
# Processing Record 36 of Set 8 | camacha
# Processing Record 37 of Set 8 | rio gallegos
# Processing Record 38 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 39 of Set 8 | malkara
# Processing Record 40 of Set 8 | spearfish
# Processing Record 41 of Set 8 | pochutla
# Processing Record 42 of Set 8 | pemangkat
# Processing Record 43 of Set 8 | ostrovnoy
# Processing Record 44 of Set 8 | karratha
# Processing Record 45 of Set 8 | roma
# Processing Record 46 of Set 8 | abu dhabi
# Processing Record 47 of Set 8 | ahipara
# Processing Record 48 of Set 8 | taltal
# Processing Record 49 of Set 8 | hailey
# Processing Record 50 of Set 8 | faanui
# Processing Record 1 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 2 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 9 | verkhnyaya inta
# Processing Record 4 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 9 | nhulunbuy
# Processing Record 6 of Set 9 | nantucket
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | erken-shakhar
# City not found. Skipping...
# Processing Record 9 of Set 9 | pasuruan
# Processing Record 10 of Set 9 | barquisimeto
# Processing Record 11 of Set 9 | benghazi
# Processing Record 12 of Set 9 | robertsport
# Processing Record 13 of Set 9 | dawson creek
# Processing Record 14 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 9 | castanas
# Processing Record 16 of Set 9 | tiksi
# Processing Record 17 of Set 9 | zhenlai
# Processing Record 18 of Set 9 | cehegin
# Processing Record 19 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 20 of Set 9 | borujan
# City not found. Skipping...
# Processing Record 21 of Set 9 | saint-georges
# Processing Record 22 of Set 9 | tilichiki
# Processing Record 23 of Set 9 | weihe
# Processing Record 24 of Set 9 | maltahohe
# Processing Record 25 of Set 9 | cherskiy
# Processing Record 26 of Set 9 | bonavista
# Processing Record 27 of Set 9 | spassk
# Processing Record 28 of Set 9 | finschhafen
# Processing Record 29 of Set 9 | zemio
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | chateau-gontier
# Processing Record 32 of Set 9 | caravelas
# Processing Record 33 of Set 9 | freeport
# Processing Record 34 of Set 9 | vaitape
# Processing Record 35 of Set 9 | barra patuca
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | banchory
# Processing Record 38 of Set 9 | palencia
# Processing Record 39 of Set 9 | colmenar viejo
# Processing Record 40 of Set 9 | sioux lookout
# Processing Record 41 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 42 of Set 9 | san ignacio
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | merauke
# Processing Record 45 of Set 9 | shepetivka
# Processing Record 46 of Set 9 | westport
# Processing Record 47 of Set 9 | okhotsk
# Processing Record 48 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 9 | sur
# Processing Record 50 of Set 9 | sakaraha
# Processing Record 1 of Set 10 | abalak
# Processing Record 2 of Set 10 | kavieng
# Processing Record 3 of Set 10 | copiapo
# Processing Record 4 of Set 10 | simav
# Processing Record 5 of Set 10 | santa vitoria
# Processing Record 6 of Set 10 | viedma
# Processing Record 7 of Set 10 | anshun
# Processing Record 8 of Set 10 | carballo
# Processing Record 9 of Set 10 | bay roberts
# Processing Record 10 of Set 10 | sharjah
# Processing Record 11 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 13 of Set 10 | chatellerault
# Processing Record 14 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 15 of Set 10 | kollo
# Processing Record 16 of Set 10 | port keats
# Processing Record 17 of Set 10 | oussouye
# Processing Record 18 of Set 10 | tabou
# Processing Record 19 of Set 10 | basyanovskiy
# City not found. Skipping...
# Processing Record 20 of Set 10 | borogontsy
# Processing Record 21 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 10 | bowen
# Processing Record 23 of Set 10 | north branch
# Processing Record 24 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 25 of Set 10 | cutervo
# Processing Record 26 of Set 10 | aksay
# Processing Record 27 of Set 10 | pallisa
# Processing Record 28 of Set 10 | ebeltoft
# Processing Record 29 of Set 10 | leningradskiy
# Processing Record 30 of Set 10 | keffi
# Processing Record 31 of Set 10 | nakusp
# Processing Record 32 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 10 | boden
# Processing Record 34 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 10 | qui nhon
# Processing Record 36 of Set 10 | luau
# Processing Record 37 of Set 10 | tutoia
# Processing Record 38 of Set 10 | jiuquan
# Processing Record 39 of Set 10 | oran
# Processing Record 40 of Set 10 | turukhansk
# Processing Record 41 of Set 10 | pangoa
# Processing Record 42 of Set 10 | ankazoabo
# Processing Record 43 of Set 10 | uruzgan
# Processing Record 44 of Set 10 | baoqing
# Processing Record 45 of Set 10 | buala
# Processing Record 46 of Set 10 | aykhal
# Processing Record 47 of Set 10 | gazojak
# Processing Record 48 of Set 10 | ahuimanu
# Processing Record 49 of Set 10 | fianga
# City not found. Skipping...
# Processing Record 50 of Set 10 | rudnogorsk
# Processing Record 1 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 3 of Set 11 | mocuba
# Processing Record 4 of Set 11 | kindu
# Processing Record 5 of Set 11 | dunedin
# Processing Record 6 of Set 11 | coihaique
# Processing Record 7 of Set 11 | bagarji
# Processing Record 8 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 11 | lata
# Processing Record 10 of Set 11 | hienghene
# Processing Record 11 of Set 11 | ancud
# Processing Record 12 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 11 | tual
# Processing Record 14 of Set 11 | umm kaddadah
# Processing Record 15 of Set 11 | yeppoon
# Processing Record 16 of Set 11 | chapleau
# Processing Record 17 of Set 11 | wehr
# Processing Record 18 of Set 11 | itarema
# Processing Record 19 of Set 11 | ajdabiya
# Processing Record 20 of Set 11 | miquelon
# Processing Record 21 of Set 11 | magadan
# Processing Record 22 of Set 11 | ziarat
# Processing Record 23 of Set 11 | vila do maio
# Processing Record 24 of Set 11 | mbanza-ngungu
# Processing Record 25 of Set 11 | birao
# Processing Record 26 of Set 11 | sechura
# Processing Record 27 of Set 11 | lorengau
# Processing Record 28 of Set 11 | zhangye
# Processing Record 29 of Set 11 | pandan
# Processing Record 30 of Set 11 | shrigonda
# Processing Record 31 of Set 11 | matara
# Processing Record 32 of Set 11 | miyako
# Processing Record 33 of Set 11 | sakaiminato
# Processing Record 34 of Set 11 | clarence town
# Processing Record 35 of Set 11 | paamiut
# Processing Record 36 of Set 11 | santiago del estero
# Processing Record 37 of Set 11 | risor
# Processing Record 38 of Set 11 | russell
# Processing Record 39 of Set 11 | bereda
# Processing Record 40 of Set 11 | ocean city
# Processing Record 41 of Set 11 | borgo san lorenzo
# Processing Record 42 of Set 11 | yulara
# Processing Record 43 of Set 11 | glenwood springs
# Processing Record 44 of Set 11 | banda aceh
# Processing Record 45 of Set 11 | angra
# City not found. Skipping...
# Processing Record 46 of Set 11 | fairbanks
# Processing Record 47 of Set 11 | carahue
# Processing Record 48 of Set 11 | cabra
# Processing Record 49 of Set 11 | martos
# Processing Record 50 of Set 11 | weligama
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | araouane
# Processing Record 3 of Set 12 | waingapu
# Processing Record 4 of Set 12 | shenjiamen
# Processing Record 5 of Set 12 | tandil
# Processing Record 6 of Set 12 | katherine
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | alice springs
# Processing Record 9 of Set 12 | ejea de los caballeros
# Processing Record 10 of Set 12 | pozo colorado
# Processing Record 11 of Set 12 | erechim
# Processing Record 12 of Set 12 | nuevo progreso
# Processing Record 13 of Set 12 | gamba
# Processing Record 14 of Set 12 | qaqortoq
# Processing Record 15 of Set 12 | padang
# Processing Record 16 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | gaoyou
# Processing Record 18 of Set 12 | san juan
# Processing Record 19 of Set 12 | babushkin
# Processing Record 20 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 12 | shelabolikha
# Processing Record 22 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 23 of Set 12 | helong
# Processing Record 24 of Set 12 | puyang
# Processing Record 25 of Set 12 | lypcha
# Processing Record 26 of Set 12 | vanimo
# Processing Record 27 of Set 12 | pedernales
# Processing Record 28 of Set 12 | half moon bay
# Processing Record 29 of Set 12 | puerto leguizamo
# Processing Record 30 of Set 12 | staraya toropa
# Processing Record 31 of Set 12 | micheweni
# Processing Record 32 of Set 12 | klaksvik
# Processing Record 33 of Set 12 | aginskoye
# Processing Record 34 of Set 12 | taketa
# Processing Record 35 of Set 12 | la ligua
# Processing Record 36 of Set 12 | houma
# Processing Record 37 of Set 12 | arkhangelsk
# Processing Record 38 of Set 12 | harper
# Processing Record 39 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 12 | coquimbo
# Processing Record 41 of Set 12 | ko samui
# Processing Record 42 of Set 12 | mudgee
# Processing Record 43 of Set 12 | sakleshpur
# Processing Record 44 of Set 12 | muravlenko
# Processing Record 45 of Set 12 | atambua
# Processing Record 46 of Set 12 | nizhniy baskunchak
# Processing Record 47 of Set 12 | san juan evangelista
# Processing Record 48 of Set 12 | kinsale
# Processing Record 49 of Set 12 | dinan
# Processing Record 50 of Set 12 | saint-pierre
# Processing Record 1 of Set 13 | ploufragan
# Processing Record 2 of Set 13 | otavalo
# Processing Record 3 of Set 13 | prachuap khiri khan
# Processing Record 4 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 13 | aguimes
# Processing Record 6 of Set 13 | novonukutskiy
# Processing Record 7 of Set 13 | kangasala
# Processing Record 8 of Set 13 | nong khai
# Processing Record 9 of Set 13 | hammerfest
# Processing Record 10 of Set 13 | asau
# Processing Record 11 of Set 13 | mikuni
# Processing Record 12 of Set 13 | luanda
# Processing Record 13 of Set 13 | katiola
# Processing Record 14 of Set 13 | makakilo city
# Processing Record 15 of Set 13 | luoyang
# Processing Record 16 of Set 13 | tukrah
# Processing Record 17 of Set 13 | luangwa
# Processing Record 18 of Set 13 | aswan
# Processing Record 19 of Set 13 | trincomalee
# Processing Record 20 of Set 13 | mongu
# Processing Record 21 of Set 13 | springdale
# Processing Record 22 of Set 13 | port-cartier
# Processing Record 23 of Set 13 | ribas do rio pardo
# Processing Record 24 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 13 | kahului
# Processing Record 26 of Set 13 | imbituba
# Processing Record 27 of Set 13 | udachnyy
# Processing Record 28 of Set 13 | vucje
# Processing Record 29 of Set 13 | muros
# Processing Record 30 of Set 13 | champerico
# Processing Record 31 of Set 13 | san vicente
# Processing Record 32 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 13 | kushiro
# Processing Record 34 of Set 13 | labod
# Processing Record 35 of Set 13 | bambanglipuro
# Processing Record 36 of Set 13 | pundaguitan
# Processing Record 37 of Set 13 | saquarema
# Processing Record 38 of Set 13 | derzhavinsk
# Processing Record 39 of Set 13 | svetlogorsk
# Processing Record 40 of Set 13 | nueve de julio
# Processing Record 41 of Set 13 | the valley
# Processing Record 42 of Set 13 | sao domingos
# Processing Record 43 of Set 13 | kibala
# Processing Record 44 of Set 13 | ambulu
# Processing Record 45 of Set 13 | marquette
# Processing Record 46 of Set 13 | majene
# Processing Record 47 of Set 13 | flin flon
# Processing Record 48 of Set 13 | baykit
# Processing Record 49 of Set 13 | pimenteiras
# Processing Record 50 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 14 | pontes e lacerda
# Processing Record 2 of Set 14 | palimbang
# Processing Record 3 of Set 14 | dvorichna
# Processing Record 4 of Set 14 | gabu
# Processing Record 5 of Set 14 | nadym
# Processing Record 6 of Set 14 | krasnovishersk
# Processing Record 7 of Set 14 | paka
# Processing Record 8 of Set 14 | rockport
# Processing Record 9 of Set 14 | yerbogachen
# Processing Record 10 of Set 14 | los llanos de aridane
# Processing Record 11 of Set 14 | corinto
# Processing Record 12 of Set 14 | capoterra
# Processing Record 13 of Set 14 | kismayo
# Processing Record 14 of Set 14 | santa marta
# Processing Record 15 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 14 | zabaykalsk
# Processing Record 17 of Set 14 | sao borja
# Processing Record 18 of Set 14 | atar
# Processing Record 19 of Set 14 | bilibino
# Processing Record 20 of Set 14 | luzhou
# Processing Record 21 of Set 14 | ternova
# Processing Record 22 of Set 14 | sinnai
# Processing Record 23 of Set 14 | groa
# Processing Record 24 of Set 14 | lampang
# Processing Record 25 of Set 14 | zhezkazgan
# Processing Record 26 of Set 14 | batticaloa
# Processing Record 27 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 14 | biltine
# Processing Record 29 of Set 14 | teguise
# Processing Record 30 of Set 14 | hackettstown
# Processing Record 31 of Set 14 | dudinka
# Processing Record 32 of Set 14 | paramirim
# Processing Record 33 of Set 14 | mansa
# Processing Record 34 of Set 14 | california city
# Processing Record 35 of Set 14 | leh
# Processing Record 36 of Set 14 | borujerd
# Processing Record 37 of Set 14 | langsa
# Processing Record 38 of Set 14 | yueyang
# Processing Record 39 of Set 14 | puerto penasco
# Processing Record 40 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 41 of Set 14 | uyaan
# Processing Record 42 of Set 14 | verkhovazhye
# Processing Record 43 of Set 14 | inta
# Processing Record 44 of Set 14 | manokwari
# Processing Record 45 of Set 14 | launceston
# Processing Record 46 of Set 14 | camana
# Processing Record 47 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 14 | bougouni
# Processing Record 49 of Set 14 | leon
# Processing Record 50 of Set 14 | joshimath
# Processing Record 1 of Set 15 | kuching
# Processing Record 2 of Set 15 | sobolevo
# Processing Record 3 of Set 15 | lavrentiya
# Processing Record 4 of Set 15 | charlestown
# Processing Record 5 of Set 15 | pahalgam
# Processing Record 6 of Set 15 | canico
# Processing Record 7 of Set 15 | vidim
# Processing Record 8 of Set 15 | irtyshskiy
# Processing Record 9 of Set 15 | nakama
# Processing Record 10 of Set 15 | maldonado
# Processing Record 11 of Set 15 | rovaniemi
# Processing Record 12 of Set 15 | irupi
# Processing Record 13 of Set 15 | kalabo
# Processing Record 14 of Set 15 | igarka
# Processing Record 15 of Set 15 | bouca
# Processing Record 16 of Set 15 | broken hill
# Processing Record 17 of Set 15 | menongue
# Processing Record 18 of Set 15 | waitati
# Processing Record 19 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 20 of Set 15 | veinticinco de mayo
# Processing Record 21 of Set 15 | brae
# Processing Record 22 of Set 15 | jiaocheng
# Processing Record 23 of Set 15 | gambela
# Processing Record 24 of Set 15 | pahrump
# Processing Record 25 of Set 15 | coruripe
# Processing Record 26 of Set 15 | ler
# Processing Record 27 of Set 15 | hongan
# City not found. Skipping...
# Processing Record 28 of Set 15 | puerto colombia
# Processing Record 29 of Set 15 | amaraji
# Processing Record 30 of Set 15 | nelson bay
# Processing Record 31 of Set 15 | takaka
# Processing Record 32 of Set 15 | mana
# Processing Record 33 of Set 15 | san luis
# Processing Record 34 of Set 15 | izumo
# Processing Record 35 of Set 15 | olinda
# Processing Record 36 of Set 15 | oil city
# Processing Record 37 of Set 15 | kayerkan
# Processing Record 38 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 15 | qeshm
# Processing Record 40 of Set 15 | pangkalanbuun
# Processing Record 41 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 15 | kharovsk
# Processing Record 43 of Set 15 | sibolga
# Processing Record 44 of Set 15 | imaichi
# Processing Record 45 of Set 15 | juneau
# Processing Record 46 of Set 15 | adeje
# Processing Record 47 of Set 15 | beringovskiy
# Processing Record 48 of Set 15 | bacolod
# Processing Record 49 of Set 15 | soyo
# Processing Record 50 of Set 15 | kegums
# Processing Record 1 of Set 16 | khovu-aksy
# Processing Record 2 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 16 | sheridan
# Processing Record 4 of Set 16 | ballina
# Processing Record 5 of Set 16 | nevers
# Processing Record 6 of Set 16 | kungurtug
# Processing Record 7 of Set 16 | bahar
# Processing Record 8 of Set 16 | aquiraz
# Processing Record 9 of Set 16 | sabha
# Processing Record 10 of Set 16 | hirara
# Processing Record 11 of Set 16 | atherton
# Processing Record 12 of Set 16 | shanghai
# Processing Record 13 of Set 16 | pafos
# Processing Record 14 of Set 16 | rorvik
# Processing Record 15 of Set 16 | the pas
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Srednekolymsk  67.4500  153.6833     34.97        88         100
# 1      Upernavik  72.7868  -56.1549     33.84        67          82
# 2        Colares  38.7992   -9.4469     69.48        67          66
# 3      Inhambane -23.8650   35.3833     66.85        72          21
# 4        Matamba  -8.9833   33.9667     50.72        79           8
#
#    Wind Speed Country Current Description
# 0       11.54      RU
# 1        3.94      GL
# 2        7.63      PT
# 3       11.68      MZ
# 4        6.42      TZ

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
